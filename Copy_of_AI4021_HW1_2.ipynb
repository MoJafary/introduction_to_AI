# %% [markdown]
# <a href="https://colab.research.google.com/github/MoJafary/introduction_to_AI/blob/main/Copy_of_AI4021_HW1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **Problem 1:** Create a NumPy array of 20 random integers between 1 and 100. Calculate the mean, median, and standard deviation of the array.

# %%
x=np.random.randint(100, size=(20))
av = np.mean(x)
med = np.median(x)
dev = np.std(x)

print(x)
print(av)
print(med)
print(dev)
# Out:
# [74 85 44 30 49 92 48 98 87 90 68 50 29  5 88 88 17 48 96 80]
# 63.3
# 71.0
# 27.864134653708522

# %% [markdown]
# **Problem 2:** Create a Pandas DataFrame with three columns - 'Name', 'Age', and 'City' - and at least five rows of data. Perform a basic data exploration by displaying the first 3 rows, the last 2 rows, and a summary of statistics for the 'Age' column.

# %%
data = {
    "Name" : ["mmd", "ali", "amir", "mehdi", "hadi"],
    "Age" : [30, 40, 41, 45, 50],
    "City" : ["tehran", "qale", "torento", "tabriz", "hamedan"],
}

df = pd.DataFrame(data)
print(df)

df.head(3)
df.tail(2)
df.describe()
# Out:
#     Name  Age     City
# 0    mmd   30   tehran
# 1    ali   40     qale
# 2   amir   41  torento
# 3  mehdi   45   tabriz
# 4   hadi   50  hamedan
#              Age
# count   5.000000
# mean   41.200000
# std     7.395945
# min    30.000000
# 25%    40.000000
# 50%    41.000000
# 75%    45.000000
# max    50.000000

# %% [markdown]
# **Problem 3:** Create a bar chart using Matplotlib to visualize the following data: Monthly sales for a store (January to May). Use appropriate labels and titles for the chart.

# %%
data = {
    'Month': ['January', 'February', 'March', 'April', 'May'],
    'Sales': [5000, 5500, 6000, 6200, 5800]
}
monthly_sales = pd.DataFrame(data)

plt.figure(figsize=(8, 6))
plt.bar(monthly_sales['Month'], monthly_sales['Sales'], color='gray')
plt.title('Monthly Sales')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# **Problem 4:** Create two NumPy arrays, 'arr1' and 'arr2', both of size 5x5 with random integer values. Perform element-wise addition, subtraction, multiplication, and division between the two arrays.

# %%
arr1 = np.random.randint(1, 11, (5, 5))
arr2 = np.random.randint(1, 11, (5, 5))

addition = arr1 + arr2
subtraction = arr1 - arr2
multiplication = arr1 * arr2
division = arr1 / arr2

print("arr1:")
print(arr1)
print("arr2:")
print(arr2)
print("Element-wise addition:")
print(addition)
print("Element-wise subtraction:")
print(subtraction)
print("Element-wise multiplication:")
print(multiplication)
print("Element-wise division:")
print(division)
# Out:
# arr1:
# [[ 5  4  5  1 10]
#  [ 7  7  3  3  9]
#  [ 9  3  6  1  7]
#  [ 8  1  6  3 10]
#  [ 7 10  8 10  5]]
# arr2:
# [[ 5  6  9  7  9]
#  [ 4  7  6  4  4]
#  [ 7  2  9  3  9]
#  [ 2  7 10  7  3]
#  [ 9  8  1 10  7]]
# Element-wise addition:
# [[10 10 14  8 19]
#  [11 14  9  7 13]
#  [16  5 15  4 16]
#  [10  8 16 10 13]
#  [16 18  9 20 12]]
# Element-wise subtraction:
# [[ 0 -2 -4 -6  1]
#  [ 3  0 -3 -1  5]
#  [ 2  1 -3 -2 -2]
#  [ 6 -6 -4 -4  7]
#  [-2  2  7  0 -2]]
# Element-wise multiplication:
# [[ 25  24  45   7  90]
#  [ 28  49  18  12  36]
#  [ 63   6  54   3  63]
#  [ 16   7  60  21  30]
#  [ 63  80   8 100  35]]
# Element-wise division:
# [[1.         0.66666667 0.55555556 0.14285714 1.11111111]
#  [1.75       1.         0.5        0.75       2.25      ]
#  [1.28571429 1.5        0.66666667 0.33333333 0.77777778]
#  [4.         0.14285714 0.6        0.42857143 3.33333333]
#  [0.77777778 1.25       8.         1.         0.71428571]]

# %% [markdown]
# **Problem 5:** Given a Pandas DataFrame with information about employees, filter and display only the employees who are older than 30 years.

# %%
data = {
    'ID': [1, 2, 3, 4, 5],
    'name': ['hadi', 'mehdi', 'amir', 'ali', 'mmd'],
    'age': [28, 35, 29, 31, 26],
    'saleri': [2000, 1350, 1444, 50, 3001]
}

employees_df = pd.DataFrame(data)

filtered_df = employees_df[employees_df['age'] > 30]

print(filtered_df)
# Out:
#    ID   name  age  saleri
# 1   2  mehdi   35    1350
# 3   4    ali   31      50

# %% [markdown]
# **Problem 6:** Create a scatter plot using Matplotlib to visualize a dataset of 100 random (x, y) coordinates. Label the axes appropriately and give the plot a title.

# %%
x = np.random.uniform(-100, 100, 100)
y = np.random.uniform(-100, 100, 100)


plt.figure(figsize=(10, 8))
plt.scatter(x, y, color='black', marker='x', alpha=0.4)
plt.title('Coordinates')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid(True)
plt.show()

# %% [markdown]
# **Problem 7:** Create two NumPy matrices, 'matrix1' (2x3) and 'matrix2' (3x4), with random values. Perform matrix multiplication between the two matrices.

# %%
matrix1 = np.random.rand(2, 3)
matrix2 = np.random.rand(3, 4)

result_matrix = np.dot(matrix1, matrix2)

print("matrix1:")
print(matrix1)
print("matrix2:")
print(matrix2)
print("matrix multiplication:")
print(result_matrix)
# Out:
# matrix1:
# [[0.77325913 0.56769275 0.98299913]
#  [0.98224778 0.99266699 0.11861552]]
# matrix2:
# [[0.93825614 0.24456961 0.45821226 0.75740656]
#  [0.20362093 0.56631161 0.18581675 0.10473611]
#  [0.11655861 0.35763903 0.00465484 0.42485392]]
# matrix multiplication:
# [[0.95568626 0.86216554 0.46437933 1.0627605 ]
#  [1.13755344 0.84480833 0.63508426 0.89832325]]

# %% [markdown]
# **Problem 8:** Given a Pandas DataFrame containing sales data, calculate and display the total sales for each product category.

# %%
data = [
    ("apple", 100),
    ("apple", 150),
    ("apple", 200),
    ("orange", 50),
    ("orange", 75),
    ("orange", 100),
    ("banana", 100),
    ("banana", 100),
    ("banana", 100),

]

product_sales = pd.DataFrame(data, columns=["Product", "Sale"])
total_sales = product_sales.groupby("Product")["Sale"].sum().reset_index()
print(total_sales)
# Out:
#   Product  Sale
# 0   apple   450
# 1  banana   300
# 2  orange   225

# %% [markdown]
# **Problem 9:** Create a line chart using Matplotlib to visualize the population growth of a city over 10 years. Label the axes and provide a title.

# %%
data = {
    'year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
    'population': [6000, 6100, 6500, 6450, 6900, 7462, 7500, 6200, 6900, 8500],
}

population_df = pd.DataFrame(data)

plt.figure(figsize=(10, 6))
plt.plot(population_df['year'], population_df['population'], marker='o', linestyle='-')
plt.title('Population Growth Over 10 Years')
plt.xlabel('Year')
plt.ylabel('Population')
plt.grid(True)
plt.show()

# %% [markdown]
# **Problem 10:** Given a Pandas DataFrame containing information about students, add a new column 'Grade' based on the following criteria:
# * If 'Score' >= 90, Grade is 'A'
# * If 'Score' >= 80, Grade is 'B'
# * If 'Score' >= 70, Grade is 'C'
# * If 'Score' < 70, Grade is 'D'

# %%
def get_grade(score):
    if score >= 90:
        return 'A'
    elif score >= 80:
        return 'B'
    elif score >= 70:
        return 'C'
    else:
        return 'D'

data = {
    'name': ['hadi', 'mehdi', 'amir', 'ali', 'mamad'],
    'Score': [92, 78, 65, 88, 68]
}

nomre_df = pd.DataFrame(data)

nomre_df['Grade'] = nomre_df['Score'].apply(get_grade)

print(nomre_df)
# Out:
#     name  Score Grade
# 0   hadi     92     A
# 1  mehdi     78     C
# 2   amir     65     D
# 3    ali     88     B
# 4  mamad     68     D

# %% [markdown]
# **Problem 11:** You are given a dataset containing monthly sales data for three products (A, B, and C) over a two-year period. Your task is to perform various data analysis tasks using NumPy, Pandas, and Matplotlib.
#
#
# *   Dataset:
#
# ```
# import pandas as pd
#
# data = {
#     'Month': pd.date_range(start='2021-01-01', periods=24, freq='M'),
#     'Product A Sales': [500, 480, 600, 750, 900, 850, 920, 1100, 1300, 1350, 1500, 1450, 1550, 1600, 1650, 1600, 1500, 1400, 1600, 1700, 1800, 1750, 1850, 1900],
#     'Product B Sales': [300, 320, 400, 450, 500, 580, 700, 750, 820, 900, 950, 980, 1050, 1100, 1150, 1200, 1250, 1300, 1350, 1400, 1500, 1600, 1550, 1700],
#     'Product C Sales': [200, 210, 250, 280, 320, 350, 380, 400, 420, 440, 460, 480, 500, 520, 540, 560, 580, 600, 620, 640, 660, 680, 700, 720]
# }
#
# sales_df = pd.DataFrame(data)
# ```
# *  Tasks:
# 1. Calculate and display the total sales for each product over the two-year period.
#
# 2. Calculate and display the average monthly sales for each product.
#
# 3. Find the month with the highest sales for each product, and display the product and the sales value for that month.
#
# 4. Calculate and display the percentage change in sales for each product from January to December in the second year (2022).
#
# 5. Create a line chart using Matplotlib to visualize the monthly sales data for each product over the two-year period. Label the axes and provide a title for the chart.
#
# 6. Calculate the correlation between Product A and Product B sales. Is there a strong correlation between these two products? Display the correlation coefficient.

# %%
data = {
    'Month': pd.date_range(start='2021-01-01', periods=24, freq='M'),
    'Product A Sales': [500, 480, 600, 750, 900, 850, 920, 1100, 1300, 1350, 1500, 1450, 1550, 1600, 1650, 1600, 1500, 1400, 1600, 1700, 1800, 1750, 1850, 1900],
    'Product B Sales': [300, 320, 400, 450, 500, 580, 700, 750, 820, 900, 950, 980, 1050, 1100, 1150, 1200, 1250, 1300, 1350, 1400, 1500, 1600, 1550, 1700],
    'Product C Sales': [200, 210, 250, 280, 320, 350, 380, 400, 420, 440, 460, 480, 500, 520, 540, 560, 580, 600, 620, 640, 660, 680, 700, 720]
}

sales_df = pd.DataFrame(data)


def calculate_total_sales(df):
    total_sales = df.iloc[:, 1:].sum()
    return total_sales

def calculate_average_monthly_sales(df):
    avg_monthly_sales = df.iloc[:, 1:].mean()
    return avg_monthly_sales


def find_highest_sales_month(df):
    result = []

    for product in df.columns[1:]:
        max_index = df[product].idxmax()
        max_month = df.loc[max_index, 'Month']
        max_sales = df.loc[max_index, product]
        result.append((product, max_month, max_sales))

    return result

def calculate_percentage_change(df):

    df_2022 = df[(df['Month'] >= '2022-01-01') & (df['Month'] <= '2022-12-31')]

    january_sales = df_2022.iloc[0, 1:]
    december_sales = df_2022.iloc[-1, 1:]

    percentage_change = ((december_sales - january_sales) / january_sales) * 100

    return percentage_change


total_sales = calculate_total_sales(sales_df)
average_sales = calculate_average_monthly_sales(sales_df)
highest_sales_months = find_highest_sales_month(sales_df)
percentage_change_2022 = calculate_percentage_change(sales_df)

print(total_sales)
print(average_sales)

for product, month, sales in highest_sales_months:
    print(f"Product: {product}, Month: {month}, Sales: {sales}")
for product, change in percentage_change_2022.items():
    print(f"Product: {product}, Percentage Change: {change:.2f}%")

plt.figure(figsize=(12, 6))
for product in sales_df.columns[1:]:
    plt.plot(sales_df['Month'], sales_df[product], label=product)
plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Monthly Sales Data for Each Product (2021-2022)')
plt.legend()
plt.grid()
plt.show()
# Out:
# Product A Sales    31600
# Product B Sales    23800
# Product C Sales    11510
# dtype: int64
# Product A Sales    1316.666667
# Product B Sales     991.666667
# Product C Sales     479.583333
# dtype: float64
# Product: Product A Sales, Month: 2022-12-31 00:00:00, Sales: 1900
# Product: Product B Sales, Month: 2022-12-31 00:00:00, Sales: 1700
# Product: Product C Sales, Month: 2022-12-31 00:00:00, Sales: 720
# Product: Product A Sales, Percentage Change: 22.58%
# Product: Product B Sales, Percentage Change: 61.90%
# Product: Product C Sales, Percentage Change: 44.00%
